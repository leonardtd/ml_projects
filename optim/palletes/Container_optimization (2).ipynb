# %%
"""
boxes = [
    [9, 9, 10],
    [9, 10, 1],
    [10, 10, 1],
    [1, 5, 10],
    [1, 5, 10]
]

boxes = [
    [9, 9, 10],
    [9, 10, 1],
    [10, 10, 1],
    [1, 10, 10]
]
"""
# Out:
# '\nboxes = [\n    [9, 9, 10],\n    [9, 10, 1],\n    [10, 10, 1],\n    [1, 5, 10],\n    [1, 5, 10]\n]\n'

# %%
import pandas as pd

# List of box dimensions: [width, height, depth]
boxes = [
    [9, 9, 10],
    [9, 10, 1],
    [10, 10, 1],
    [1, 5, 10],
    [1, 5, 10]
]

#width, height, and depth of the Container
W, H, D = 10, 11, 10

df = pd.DataFrame(columns=['Box_ID', 'Width', 'Height', 'Depth'])

for idx, box in enumerate(boxes):
    df.loc[idx] = [idx+1] + box  # Box_ID starts from 1, hence idx+1
    
df['Volume'] = df.Width*df.Height*df.Depth

df
# Out:
#    Box_ID  Width  Height  Depth  Volume
# 0       1      9       9     10     810
# 1       2      9      10      1      90
# 2       3     10      10      1     100
# 3       4      1       5     10      50
# 4       5      1       5     10      50

# %%
from pulp import LpMaximize, LpProblem, LpVariable, lpSum
import pulp

# Define the problem
model = LpProblem(name="3D-knapsack-problem", sense=LpMaximize)

# Large number for M
M = 10000

# Number of boxes (assumption)
n_boxes = df.shape[0]

# Box dimensions (example)
w = list(df.Width)
h = list(df.Height)
d = list(df.Depth)

# Box values (example)
box_values = list(df.Volume)

# %%
# Define variables
n = n_boxes

# LBB coordinates of each box
x = [LpVariable(name=f"x_{i}", lowBound=0) for i in range(n_boxes)]
y = [LpVariable(name=f"y_{i}", lowBound=0) for i in range(n_boxes)]
z = [LpVariable(name=f"z_{i}", lowBound=0) for i in range(n_boxes)]

"""
# Left-Bottom Behind (LBB) coordinates of the preplaced boxes (obstacles)
r = [LpVariable(name=f"r_{i}", lowBound=0) for i in range(n)]
s = [LpVariable(name=f"s_{i}", lowBound=0) for i in range(n)]
k = [LpVariable(name=f"k_{i}", lowBound=0) for i in range(n)]

# Binary orientation parameters for preplaced boxes
a = [LpVariable(name=f"a_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n)]
b = [LpVariable(name=f"b_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n)]
c = [LpVariable(name=f"c_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n)]
d = [LpVariable(name=f"d_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n)]
"""

# Orientation variables
X_w = [LpVariable(name=f"X_w_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n_boxes)]
Z_w = [LpVariable(name=f"Z_w_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n_boxes)]
Y_h = [LpVariable(name=f"Y_h_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n_boxes)]
Z_d = [LpVariable(name=f"Z_d_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n_boxes)]

# Initialize r, l, b, f, o, u variables
r_ij = [[LpVariable(name=f"r_{i}{j}", lowBound=0, upBound=1, cat="Binary") if i != j else None for j in range(n)] for i in range(n_boxes)]
l_ij = [[LpVariable(name=f"l_{i}{j}", lowBound=0, upBound=1, cat="Binary") if i != j else None for j in range(n)] for i in range(n_boxes)]
b_ij = [[LpVariable(name=f"b_{i}{j}", lowBound=0, upBound=1, cat="Binary") if i != j else None for j in range(n)] for i in range(n_boxes)]
f_ij = [[LpVariable(name=f"f_{i}{j}", lowBound=0, upBound=1, cat="Binary") if i != j else None for j in range(n)] for i in range(n_boxes)]
o_ij = [[LpVariable(name=f"o_{i}{j}", lowBound=0, upBound=1, cat="Binary") if i != j else None for j in range(n)] for i in range(n_boxes)]
u_ij = [[LpVariable(name=f"u_{i}{j}", lowBound=0, upBound=1, cat="Binary") if i != j else None for j in range(n)] for i in range(n_boxes)]

# Whether box i is packed
s = [LpVariable(name=f"s_{i}", lowBound=0, upBound=1, cat='Binary') for i in range(n_boxes)]

# Other variables as per your requirements
y_ij_a = [[LpVariable(name=f"y_a_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
x_ij_a = [[LpVariable(name=f"x_a_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
y_ij_b = [[LpVariable(name=f"y_b_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
x_ij_b = [[LpVariable(name=f"x_b_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
y_ij_c = [[LpVariable(name=f"y_c_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
x_ij_c = [[LpVariable(name=f"x_c_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
y_ij_d = [[LpVariable(name=f"y_d_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
x_ij_d = [[LpVariable(name=f"x_d_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
z_ij_a = [[LpVariable(name=f"z_a_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
z_ij_b = [[LpVariable(name=f"z_b_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
z_ij_c = [[LpVariable(name=f"z_c_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
z_ij_d = [[LpVariable(name=f"z_d_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
Cs_1ij = [[LpVariable(name=f"Cs_1_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
Cs_2ij = [[LpVariable(name=f"Cs_2_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
Cs_3ij = [[LpVariable(name=f"Cs_3_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]
Cs_4ij = [[LpVariable(name=f"Cs_4_{i}_{j}", lowBound=0, upBound=1, cat='Binary') if i != j else None for j in range(n_boxes)] for i in range(n_boxes)]

x_prime = [LpVariable(name=f"x_prime_{i}", lowBound=0) for i in range(n_boxes)]
z_prime = [LpVariable(name=f"z_prime_{i}", lowBound=0) for i in range(n_boxes)]

# %%
# Objective function: MAX Σ{from i=1 to n}Pi * si
model += lpSum([box_values[i] * s[i] for i in range(n_boxes)]), "Objective"


# Constraint (1)
for i in range(n):
    for j in range(n):
        if i != j:
            model += r_ij[i][j] + l_ij[i][j] + b_ij[i][j] + f_ij[i][j] + o_ij[i][j] + u_ij[i][j] == s[i] + s[j] - 1

# Constraint (2)
for i in range(n):
    for j in range(n):
        if i != j:

            # Constraint 2a
            model += x[i] + w[i]*X_w[i] + h[i]*(Z_w[i] - Y_h[i] + Z_d[i]) + d[i]*(1 - X_w[i] - Z_w[i] + Y_h[i] - Z_d[i]) <= x[j] + M*(1 - l_ij[i][j])
            
            # Constraint 2b
            model += x[j] + w[j]*X_w[j] + h[j]*(Z_w[j] - Y_h[j] + Z_d[j]) + d[j]*(1 - X_w[j] - Z_w[j] + Y_h[j] - Z_d[j]) <= x[i] + M*(1 - r_ij[i][j])
            
            # Constraint 2c
            model += z[i] + d[i]*Z_d[i] + h[i]*(1 - Z_w[i] - Z_d[i]) + w[i]*Z_w[i] <= z[j] + M*(1 - b_ij[i][j])
            
            # Constraint 2d
            model += z[j] + d[j]*Z_d[j] + h[j]*(1 - Z_w[j] - Z_d[j]) + w[j]*Z_w[j] <= z[i] + M*(1 - f_ij[i][j])
            
            # Constraint 2e
            model += y[i] + h[i]*Y_h[i] + w[i]*(1 - X_w[i] - Z_w[i]) + d[i]*(X_w[i] + Z_w[i] - Y_h[i]) <= y[j] + M*(1 - u_ij[i][j])
            
            # Constraint 2f
            model += y[j] + h[j]*Y_h[j] + w[j]*(1 - X_w[j] - Z_w[j]) + d[j]*(X_w[j] + Z_w[j] - Y_h[j]) <= y[i] + M*(1 - o_ij[i][j])
            
# Constraint (3)
for i in range(n):
    # Constraint 3a
    model += x[i] + w[i]*X_w[i] + h[i]*(Z_w[i] - Y_h[i] + Z_d[i]) + d[i]*(1 - X_w[i] - Z_w[i] + Y_h[i] - Z_d[i]) <= W
    
    # Constraint 3b
    model += y[i] + h[i]*Y_h[i] + w[i]*(1 - X_w[i] - Z_w[i]) + d[i]*(X_w[i] + Z_w[i] - Y_h[i]) <= H
    
    # Constraint 3c
    model += z[i] + d[i]*Z_d[i] + h[i]*(1 - Z_w[i] - Z_d[i]) + w[i]*Z_w[i] <= D
    
# Constraint (4)
for i in range(n):
    
    # Constraint 4a
    model += X_w[i] + Z_w[i] <= 1
    
    # Constraint 4b
    model += Z_w[i] + Z_d[i] <= 1
    
    # Constraint 4c
    model += Z_w[i] - Y_h[i] + Z_d[i] >= 0
    model += Z_w[i] - Y_h[i] + Z_d[i] <= 1
    
    # Constraint 4d
    model += 1 - X_w[i] - Z_w[i] + Y_h[i] - Z_d[i] >= 0
    model += 1 - X_w[i] - Z_w[i] + Y_h[i] - Z_d[i] <= 1
    
    # Constraint 4e
    model += X_w[i] + Z_w[i] - Y_h[i] >= 0
    model += X_w[i] + Z_w[i] - Y_h[i] <= 1
    

"""
# Constraint (5)
for i in range(n):
    model += x[i] == r  # xi = r
    model += y[i] == s  # yi = s
    model += z[i] == k  # zi = k

# Constraint (6)
for i in Pb:  # Replace 'Pb' with the actual set of indices
    model += X_w[i] == a  # X_wi = a
    model += Z_w[i] == b  # Z_wi = b
    model += Z_d[i] == c  # Z_di = c
    model += Y_h[i] == d  # Y_hi = d
"""

# Constraint (7)
for i in range(n):
    for j in range(n):
        if i != j:
            
            # Constraint 7a
            model += x[j] - x[i] <= M * y_ij_a[i][j]
            model += x[j] - x[i] >= M * (y_ij_a[i][j] - 1)

            # Constraint 7b
            model += x_prime[i] - x[j] <= M * x_ij_a[i][j]
            model += x_prime[i] - x[j] >= M * (x_ij_a[i][j] - 1) + 0.5
            
            # Constraint 7c
            model += z_ij_a[i][j] >= (y_ij_a[i][j] + x_ij_a[i][j] - 1) / 2
            model += z_ij_a[i][j] <= (y_ij_a[i][j] + x_ij_a[i][j]) / 2          
            
# Constraint (8)
for i in range(n):
    for j in range(n):
        if i != j:
            # Constraint 8a
            model += z[j] - z[i] <= M * y_ij_b[i][j]
            model += z[j] - z[i] >= M * (y_ij_b[i][j] - 1)
            
            # Constraint 8b
            model += z_prime[i] - z[j] <= M * x_ij_b[i][j]
            model += z_prime[i] - z[j] >= M * (x_ij_b[i][j] - 1) + 0.5
            
            # Constraint 8c
            model += (z_ij_b[i][j]) >= ((y_ij_b[i][j] + x_ij_b[i][j] - 1) / 2)
            model += (z_ij_b[i][j]) <= ((y_ij_b[i][j] + x_ij_b[i][j]) / 2)
            
# Constraint (9)
for i in range(n):
    for j in range(n):
        if i != j:
            # Constraint 9a
            model += x_prime[j] - x[i] <= M * y_ij_c[i][j]
            model += x_prime[j] - x[i] >= M * (y_ij_c[i][j] - 1) + 0.5
            
            # Constraint 9b
            model += x_prime[i] - x_prime[j] <= M * x_ij_c[i][j]
            model += x_prime[i] - x_prime[j] >= M * (x_ij_c[i][j] - 1)
            
            # Constraint 9c
            model += (z_ij_c[i][j]) >= ((y_ij_c[i][j] + x_ij_c[i][j] - 1) / 2)
            model += (z_ij_c[i][j]) <= ((y_ij_c[i][j] + x_ij_c[i][j]) / 2)

# Constraint (10)
for i in range(n):
    for j in range(n):
        if i != j:
            # Constraint 10a
            model += z_prime[j] - z[i] <= M * y_ij_d[i][j]
            model += z_prime[j] - z[i] >= M * (y_ij_d[i][j] - 1) + 0.5
            
            # Constraint 10b
            model += z_prime[i] - z_prime[j] <= M * x_ij_d[i][j]
            model += z_prime[i] - z_prime[j] >= M * (x_ij_d[i][j] - 1)
            
            # Constraint 10c
            model += (z_ij_d[i][j]) >= ((y_ij_d[i][j] + x_ij_d[i][j] - 1) / 2)
            model += (z_ij_d[i][j]) <= ((y_ij_d[i][j] + x_ij_d[i][j]) / 2)

# Constraint 11, 12, 13, 14, 15
for i in range(n):
    for j in range(n):
        if i != j:
            
            # Constraint 11
            model += Cs_1ij[i][j] >= ((z_ij_a[i][j] + z_ij_b[i][j] - 1) / 2)
            model += Cs_1ij[i][j] <= ((z_ij_a[i][j] + z_ij_b[i][j]) / 2)
            
            # Constraint 12
            model += Cs_2ij[i][j] >= ((z_ij_a[i][j] + z_ij_d[i][j] - 1) / 2)
            model += Cs_2ij[i][j] <= ((z_ij_a[i][j] + z_ij_d[i][j]) / 2)
            
            # Constraint 13
            model += Cs_3ij[i][j] >= ((z_ij_c[i][j] + z_ij_b[i][j] - 1) / 2)
            model += Cs_3ij[i][j] <= ((z_ij_c[i][j] + z_ij_b[i][j]) / 2)
            
            # Constraint 14
            model += Cs_4ij[i][j] >= ((z_ij_c[i][j] + z_ij_d[i][j] - 1) / 2)
            model += Cs_4ij[i][j] <= ((z_ij_c[i][j] + z_ij_d[i][j]) / 2)
            
            # Constraint 15
            model += Cs_1ij[i][j] + Cs_2ij[i][j] + Cs_3ij[i][j] + Cs_4ij[i][j] == u_ij[i][j] + o_ij[i][j]

# Constraint 16, 17
for i in range(n):
    # Constraint 16
    model += x_prime[i] == x[i] + w[i] * X_w[i] + h[i] * (Z_w[i] - Y_h[i] + Z_d[i]) + d[i] * (1 - X_w[i] - Z_w[i] + Y_h[i] - Z_d[i])
    
    # Constraint 17
    model += z_prime[i] == z[i] + d[i] * Z_d[i] + h[i] * (1 - Z_w[i] - Z_d[i]) + w[i] * Z_w[i]

# %%
# Solve the problem
model.solve(pulp.PULP_CBC_CMD(threads=None, msg=1))  # Use all available CPU cores, display log messages
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /var/tmp/7c14d5e50c054568a79debbec49e5e5c-pulp.mps max timeMode elapsed branch printingOptions all solution /var/tmp/7c14d5e50c054568a79debbec49e5e5c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 870 COLUMNS
# At line 4956 RHS
# At line 5822 BOUNDS
# At line 6288 ENDATA
# Problem MODEL has 865 rows, 490 columns and 3130 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1100 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 129 strengthened rows, 16 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 114 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 95 strengthened rows, 4 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 88 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 74 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 522 rows, 480 columns (455 integer (455 of which binary)) and 2722 elements
# Cbc0045I 5 integer variables out of 455 objects (455 integer) have costs - high priority
# Cbc0045I branch on satisfied Y create fake objective Y random cost Y
# Cbc0038I Initial state - 177 integers unsatisfied sum - 14.0542
# Cbc0038I Pass   1: suminf.    3.16106 (118) obj. -1079.69 iterations 210
# Cbc0038I Pass   2: suminf.    2.93294 (125) obj. -1086.41 iterations 41
# Cbc0038I Pass   3: suminf.    0.43162 (104) obj. -1009.78 iterations 44
# Cbc0038I Pass   4: suminf.    0.43162 (104) obj. -1009.78 iterations 0
# Cbc0038I Pass   5: suminf.    1.06248 (108) obj. -1009.77 iterations 26
# Cbc0038I Pass   6: suminf.    0.60023 (107) obj. -1009.77 iterations 18
# Cbc0038I Pass   7: suminf.    0.94220 (93) obj. -1010 iterations 19
# Cbc0038I Pass   8: suminf.    0.62624 (93) obj. -1010 iterations 4
# Cbc0038I Pass   9: suminf.   14.49236 (156) obj. -1054.98 iterations 211
# Cbc0038I Pass  10: suminf.    8.84928 (126) obj. -1066.72 iterations 67
# Cbc0038I Pass  11: suminf.    8.16656 (133) obj. -1081.59 iterations 16
# Cbc0038I Pass  12: suminf.    2.09669 (127) obj. -1095.29 iterations 44
# Cbc0038I Pass  13: suminf.    2.09663 (124) obj. -1095.29 iterations 3
# Cbc0038I Pass  14: suminf.    0.17285 (119) obj. -1009.8 iterations 68
# Cbc0038I Pass  15: suminf.    0.17165 (119) obj. -1009.83 iterations 9
# Cbc0038I Pass  16: suminf.    0.13798 (125) obj. -1009.95 iterations 34
# Cbc0038I Pass  17: suminf.    0.10827 (109) obj. -1009.95 iterations 30
# Cbc0038I Pass  18: suminf.    0.13398 (121) obj. -1009.95 iterations 28
# Cbc0038I Pass  19: suminf.   13.35486 (162) obj. -1054.89 iterations 196
# Cbc0038I Pass  20: suminf.    8.93171 (135) obj. -1083.85 iterations 73
# Cbc0038I Pass  21: suminf.    7.68143 (136) obj. -1083.93 iterations 17
# Cbc0038I Pass  22: suminf.    7.68143 (137) obj. -1083.93 iterations 1
# Cbc0038I Pass  23: suminf.    1.88021 (120) obj. -1099.88 iterations 63
# Cbc0038I Pass  24: suminf.    1.86321 (119) obj. -1097.25 iterations 6
# Cbc0038I Pass  25: suminf.    0.11172 (109) obj. -1009.56 iterations 91
# Cbc0038I Pass  26: suminf.    0.11102 (107) obj. -1009.87 iterations 10
# Cbc0038I Pass  27: suminf.    0.09323 (106) obj. -1009.56 iterations 43
# Cbc0038I Pass  28: suminf.    0.09303 (110) obj. -1009.56 iterations 1
# Cbc0038I Pass  29: suminf.    0.10502 (102) obj. -1009.87 iterations 34
# Cbc0038I Pass  30: suminf.    0.10502 (102) obj. -1009.87 iterations 0
# Cbc0038I Pass  31: suminf.    0.09253 (113) obj. -1009.57 iterations 30
# Cbc0038I Pass  32: suminf.    0.09253 (113) obj. -1009.57 iterations 1
# Cbc0038I Pass  33: suminf.    0.10402 (101) obj. -1009.87 iterations 33
# Cbc0038I Pass  34: suminf.    0.10402 (101) obj. -1009.87 iterations 0
# Cbc0038I Pass  35: suminf.   11.30104 (142) obj. -1081.98 iterations 128
# Cbc0038I Pass  36: suminf.    4.72476 (112) obj. -1083.39 iterations 78
# Cbc0038I Pass  37: suminf.    4.22476 (111) obj. -1083.39 iterations 2
# Cbc0038I Pass  38: suminf.    0.05188 (101) obj. -1009.34 iterations 96
# Cbc0038I Pass  39: suminf.    0.04532 (106) obj. -1009.91 iterations 51
# Cbc0038I Pass  40: suminf.    0.04532 (106) obj. -1009.91 iterations 0
# Cbc0038I Pass  41: suminf.   14.95397 (173) obj. -1097.29 iterations 238
# Cbc0038I Pass  42: suminf.    8.51171 (145) obj. -1099.72 iterations 123
# Cbc0038I Pass  43: suminf.    7.50878 (140) obj. -1099.72 iterations 10
# Cbc0038I Pass  44: suminf.    2.03256 (116) obj. -1099.58 iterations 55
# Cbc0038I Pass  45: suminf.    2.03225 (123) obj. -1099.64 iterations 13
# Cbc0038I Pass  46: suminf.    1.23377 (131) obj. -1099.6 iterations 45
# Cbc0038I Pass  47: suminf.    0.77742 (134) obj. -1099.63 iterations 6
# Cbc0038I Pass  48: suminf.    0.62043 (124) obj. -1099.61 iterations 23
# Cbc0038I Pass  49: suminf.    0.62031 (125) obj. -1099.62 iterations 2
# Cbc0038I Pass  50: suminf.    0.57902 (128) obj. -1099.59 iterations 20
# Cbc0038I Pass  51: suminf.    0.57858 (132) obj. -1099.68 iterations 6
# Cbc0038I Pass  52: suminf.    0.62103 (119) obj. -1099.6 iterations 17
# Cbc0038I Pass  53: suminf.   21.95321 (166) obj. -1100 iterations 244
# Cbc0038I Pass  54: suminf.   13.80696 (138) obj. -1078.65 iterations 134
# Cbc0038I Pass  55: suminf.   13.10137 (131) obj. -1078.65 iterations 16
# Cbc0038I Pass  56: suminf.   12.38586 (128) obj. -1077.97 iterations 17
# Cbc0038I Pass  57: suminf.    6.89660 (132) obj. -1097.02 iterations 59
# Cbc0038I Pass  58: suminf.    6.89580 (132) obj. -1097.02 iterations 6
# Cbc0038I Pass  59: suminf.    4.66356 (129) obj. -1096.87 iterations 61
# Cbc0038I Pass  60: suminf.    3.57497 (129) obj. -1099.3 iterations 97
# Cbc0038I Pass  61: suminf.    3.35759 (130) obj. -1099.3 iterations 2
# Cbc0038I Pass  62: suminf.    2.58389 (132) obj. -1099.42 iterations 66
# Cbc0038I Pass  63: suminf.    2.58314 (132) obj. -1099.42 iterations 2
# Cbc0038I Pass  64: suminf.    2.86868 (118) obj. -1099.68 iterations 68
# Cbc0038I Pass  65: suminf.    2.86685 (117) obj. -1099.68 iterations 4
# Cbc0038I Pass  66: suminf.    2.29607 (121) obj. -1099.64 iterations 42
# Cbc0038I Pass  67: suminf.    2.29557 (121) obj. -1099.64 iterations 3
# Cbc0038I Pass  68: suminf.    2.33971 (118) obj. -1099.66 iterations 24
# Cbc0038I Pass  69: suminf.    2.33788 (117) obj. -1099.66 iterations 3
# Cbc0038I Pass  70: suminf.    2.79357 (119) obj. -1099.64 iterations 26
# Cbc0038I Pass  71: suminf.    2.79307 (119) obj. -1099.64 iterations 3
# Cbc0038I Pass  72: suminf.    2.33725 (119) obj. -1099.65 iterations 30
# Cbc0038I Pass  73: suminf.    2.33542 (118) obj. -1099.65 iterations 3
# Cbc0038I Pass  74: suminf.    2.29360 (120) obj. -1099.64 iterations 28
# Cbc0038I Pass  75: suminf.    2.29310 (120) obj. -1099.64 iterations 3
# Cbc0038I Pass  76: suminf.   23.43023 (177) obj. -1099.63 iterations 308
# Cbc0038I Pass  77: suminf.   15.42892 (149) obj. -1088.82 iterations 92
# Cbc0038I Pass  78: suminf.   12.62295 (140) obj. -1093.14 iterations 22
# Cbc0038I Pass  79: suminf.   11.94387 (139) obj. -1093.14 iterations 2
# Cbc0038I Pass  80: suminf.   11.68784 (132) obj. -1093.87 iterations 7
# Cbc0038I Pass  81: suminf.   11.18784 (131) obj. -1093.87 iterations 1
# Cbc0038I Pass  82: suminf.    3.72411 (140) obj. -1095.44 iterations 62
# Cbc0038I Pass  83: suminf.    3.72411 (140) obj. -1095.44 iterations 0
# Cbc0038I Pass  84: suminf.    6.80292 (137) obj. -1054.35 iterations 116
# Cbc0038I Pass  85: suminf.    2.30527 (117) obj. -1009.94 iterations 42
# Cbc0038I Pass  86: suminf.    1.30554 (123) obj. -1009.94 iterations 10
# Cbc0038I Pass  87: suminf.    1.30528 (121) obj. -1009.95 iterations 5
# Cbc0038I Pass  88: suminf.    1.10666 (107) obj. -1009.95 iterations 30
# Cbc0038I Pass  89: suminf.    0.10322 (107) obj. -1009.95 iterations 7
# Cbc0038I Pass  90: suminf.    0.10322 (107) obj. -1009.95 iterations 1
# Cbc0038I Pass  91: suminf.    0.30395 (113) obj. -1009.95 iterations 25
# Cbc0038I Pass  92: suminf.    0.30395 (113) obj. -1009.95 iterations 0
# Cbc0038I Pass  93: suminf.    0.10322 (107) obj. -1009.95 iterations 26
# Cbc0038I Pass  94: suminf.   12.84809 (164) obj. -1100 iterations 244
# Cbc0038I Pass  95: suminf.    6.91676 (150) obj. -1094.5 iterations 124
# Cbc0038I Pass  96: suminf.    6.08966 (152) obj. -1096.53 iterations 33
# Cbc0038I Pass  97: suminf.    6.08966 (152) obj. -1096.53 iterations 0
# Cbc0038I Pass  98: suminf.    3.39485 (139) obj. -1099.3 iterations 91
# Cbc0038I Pass  99: suminf.    1.99336 (132) obj. -1099.62 iterations 13
# Cbc0038I Pass 100: suminf.   19.39425 (170) obj. -1099.27 iterations 170
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 522 rows 480 columns, reduced to 514 rows 455 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.32 seconds)
# Cbc0038I Full problem 523 rows 480 columns, reduced to 523 rows 480 columns - too large
# Cbc0038I After 0.36 seconds - Feasibility pump exiting - took 0.27 seconds
# Cbc0031I 105 added rows had average density of 9.3333333
# Cbc0013I At root node, 105 cuts changed objective from -1100 to -1100 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 5275 row cuts average 3.2 elements, 0 column cuts (0 active)  in 0.322 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1357 row cuts average 84.4 elements, 0 column cuts (0 active)  in 0.165 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 1023 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.094 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1145 row cuts average 5.9 elements, 0 column cuts (0 active)  in 0.100 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 287 row cuts average 2.4 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 807 row cuts average 40.9 elements, 0 column cuts (0 active)  in 0.071 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -1100 (2.90 seconds)
# Cbc0010I After 1000 nodes, 23 on tree, 1e+50 best solution, best possible -1100 (10.66 seconds)
# Cbc0010I After 2000 nodes, 58 on tree, 1e+50 best solution, best possible -1100 (14.74 seconds)
# Cbc0010I After 3000 nodes, 58 on tree, 1e+50 best solution, best possible -1100 (17.56 seconds)
# Cbc0010I After 4000 nodes, 53 on tree, 1e+50 best solution, best possible -1100 (20.33 seconds)
# Cbc0010I After 5000 nodes, 43 on tree, 1e+50 best solution, best possible -1100 (22.93 seconds)
# Cbc0012I Integer solution of -1050 found by rounding after 127157 iterations and 5114 nodes (23.67 seconds)
# Cbc0038I Full problem 522 rows 480 columns, reduced to 245 rows 127 columns
# Cbc0038I Full problem 522 rows 480 columns, reduced to 282 rows 165 columns
# Cbc0038I Full problem 522 rows 480 columns, reduced to 162 rows 100 columns
# Cbc0038I Full problem 522 rows 480 columns, reduced to 265 rows 150 columns
# Cbc0038I Full problem 522 rows 480 columns, reduced to 179 rows 106 columns
# Cbc0038I Full problem 522 rows 480 columns, reduced to 255 rows 144 columns
# Cbc0010I After 6000 nodes, 35 on tree, -1050 best solution, best possible -1100 (26.65 seconds)
# Cbc0038I Full problem 522 rows 480 columns, reduced to 303 rows 172 columns - too large
# Cbc0038I Full problem 522 rows 480 columns, reduced to 252 rows 138 columns
# Cbc0038I Full problem 522 rows 480 columns, reduced to 259 rows 144 columns
# Cbc0010I After 7000 nodes, 20 on tree, -1050 best solution, best possible -1100 (29.39 seconds)
# Cbc0038I Full problem 522 rows 480 columns, reduced to 52 rows 54 columns
# Cbc0010I After 8000 nodes, 43 on tree, -1050 best solution, best possible -1100 (32.89 seconds)
# Cbc0038I Full problem 522 rows 480 columns, reduced to 277 rows 166 columns
# Cbc0038I Full problem 522 rows 480 columns, reduced to 100 rows 77 columns
# Cbc0010I After 9000 nodes, 38 on tree, -1050 best solution, best possible -1100 (35.81 seconds)
# Cbc0010I After 10000 nodes, 50 on tree, -1050 best solution, best possible -1100 (38.90 seconds)
# Cbc0012I Integer solution of -1100 found by rounding after 221900 iterations and 10057 nodes (39.04 seconds)
# Cbc0001I Search completed - best objective -1100, took 221900 iterations and 10057 nodes (39.04 seconds)
# Cbc0032I Strong branching done 40412 times (233856 iterations), fathomed 801 nodes and fixed 6421 variables
# Cbc0035I Maximum depth 81, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -1100 to -1100
# Probing was tried 100 times and created 5275 cuts of which 0 were active after adding rounds of cuts (0.322 seconds)
# Gomory was tried 100 times and created 1357 cuts of which 0 were active after adding rounds of cuts (0.165 seconds)
# Knapsack was tried 100 times and created 1023 cuts of which 0 were active after adding rounds of cuts (0.094 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# MixedIntegerRounding2 was tried 100 times and created 1145 cuts of which 0 were active after adding rounds of cuts (0.100 seconds)
# FlowCover was tried 100 times and created 287 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# TwoMirCuts was tried 100 times and created 807 cuts of which 0 were active after adding rounds of cuts (0.071 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ImplicationCuts was tried 29 times and created 1638 cuts of which 0 were active after adding rounds of cuts (0.047 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1100.00000000
# Enumerated nodes:               10057
# Total iterations:               221900
# Time (CPU seconds):             38.97
# Time (Wallclock seconds):       39.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       38.98   (Wallclock seconds):       39.07
# 1

# %%
for i in range(n_boxes):
    print(f'The box {i+1} is packed = {s[i].varValue}')
    print(f'For box {i+1} (LBB) coordinates = {x[i].varValue}, {y[i].varValue}, {z[i].varValue}')
    print(f'For box {i+1} orientation flags = {X_w[i].varValue}, {Z_w[i].varValue}, {Y_h[i].varValue}, {Z_d[i].varValue}')
    print('------------------------------------------------')
# Out:
# The box 1 is packed = 1.0
# For box 1 (LBB) coordinates = 0.0, 1.0, 0.0
# For box 1 orientation flags = 0.0, 1.0, 0.0, 0.0
# ------------------------------------------------
# The box 2 is packed = 1.0
# For box 2 (LBB) coordinates = 0.0, 1.0, 9.0
# For box 2 orientation flags = 1.0, 0.0, 1.0, 1.0
# ------------------------------------------------
# The box 3 is packed = 1.0
# For box 3 (LBB) coordinates = 0.0, 0.0, 0.0
# For box 3 orientation flags = 0.0, 1.0, 0.0, 0.0
# ------------------------------------------------
# The box 4 is packed = 1.0
# For box 4 (LBB) coordinates = 9.0, 1.0, 5.0
# For box 4 orientation flags = 1.0, 0.0, 0.0, 0.0
# ------------------------------------------------
# The box 5 is packed = 1.0
# For box 5 (LBB) coordinates = 9.0, 1.0, 0.0
# For box 5 orientation flags = 1.0, 0.0, 0.0, 0.0
# ------------------------------------------------

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def adjust_dimensions(w, h, d, X_w, Z_w, Y_h, Z_d):
    """Adjust dimensions based on orientation flags."""
    if X_w==0 and Z_w==0 and Y_h==0 and Z_d==0:
        dx, dy, dz = d, w, h
    elif X_w==0 and Z_w==0 and Y_h==0 and Z_d==1:
        dx, dy, dz = h, w, d
    elif X_w==0 and Z_w==1 and Y_h==0 and Z_d==0:
        dx, dy, dz = h, d, w
    elif X_w==0 and Z_w==1 and Y_h==1 and Z_d==0:
        dx, dy, dz = d, h, w
    elif X_w==1 and Z_w==0 and Y_h==0 and Z_d==0:
        dx, dy, dz = w, d, h
    elif X_w==1 and Z_w==0 and Y_h==1 and Z_d==1:
        dx, dy, dz = w, h, d
    return dx, dy, dz

# Initialize the figure and 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Coordinates, dimensions, and orientation flags for each box
coordinates = [(x[i].varValue, y[i].varValue, z[i].varValue) for i in range(n_boxes)]
dimensions = [(df.Width[i], df.Height[i], df.Depth[i]) for i in range(n_boxes)]
orientation_flags = [(X_w[i].varValue, Z_w[i].varValue, Y_h[i].varValue, Z_d[i].varValue) for i in range(n_boxes)]

packed = [(s[i].varValue) for i in range(n_boxes)]

# Create empty lists to store custom legend information
legend_patches = []
legend_labels = []

# Plot each box
for i, ((x, y, z), (w, h, d), (X_w, Z_w, Y_h, Z_d), (s)) in enumerate(zip(coordinates, dimensions, orientation_flags, packed)):
    if s == 1.0:
        color = f'C{i}'  # Color for the box

        # Adjust dimensions
        dx, dy, dz = adjust_dimensions(w, h, d, X_w, Z_w, Y_h, Z_d)

        ax.bar3d(x, y, z, dx, dy, dz, color=color, alpha=0.6)

        # Legend preparation
        patch = plt.Rectangle((0, 0), 1, 1, fc=color)
        legend_patches.append(patch)
        legend_labels.append(f'Box {i + 1}')
    else:
        pass

# Setting up axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Adding custom legend
ax.legend(legend_patches, legend_labels, loc=2)

plt.show()

# %%
from pulp import LpMaximize, LpProblem, LpVariable, lpSum
import pulp

# Initialize the problem with the LpMaximize goal
lp_problem = LpProblem(name="My_LP_Problem", sense=LpMaximize)

# Define the decision variables
x1 = LpVariable(name="x1", lowBound=0)
x2 = LpVariable(name="x2", lowBound=0)

# Add the objective function to the problem
lp_problem += lpSum([4*x1, 3*x2]), "Z"

# Add the constraints
lp_problem += (2*x1 + x2 <= 8, "Constraint_1")
lp_problem += (x1 + 2*x2 <= 6, "Constraint_2")

# Solve the problem
lp_problem.solve()

# Output results
print(f"Status: {lp_problem.status}, {pulp.LpStatus[lp_problem.status]}")
print(f"x1 = {x1.varValue}")
print(f"x2 = {x2.varValue}")
print(f"Objective function value = {lp_problem.objective.value()}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /var/tmp/473ad2d6a95d4793880fd69f4b74f6dc-pulp.mps max timeMode elapsed branch printingOptions all solution /var/tmp/473ad2d6a95d4793880fd69f4b74f6dc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 14 RHS
# At line 17 BOUNDS
# At line 18 ENDATA
# Problem MODEL has 2 rows, 2 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (0) rows, 2 (0) columns and 4 (0) elements
# 0  Obj -0 Dual inf 6.9999998 (2)
# 0  Obj -0 Dual inf 6.9999998 (2)
# 2  Obj 17.333333
# Optimal - objective value 17.333333
# Optimal objective 17.33333333 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Status: 1, Optimal
# x1 = 3.3333333
# x2 = 1.3333333
# Objective function value = 17.3333331
